# %%
#mẫu về cách gọi train 
#train(model,loss_func,X,y,epochs=1000,batch_size = 32,lr=0.01):

# %%
import numpy as np
from layers import Linear 
from activations import Sigmoid, ReLU
from losses import BCE
from train_loop import train 
#Linear phải chain với nhau - ví dụ đầu tiên là Linear(2,5) thì cái tiếp theo là Linear(5,..)
#Linear(2,5) -> 5 sẽ là số neuron ,Linear(5,4) sẽ là 4 neuron

NN_demo = [Linear(2,5),ReLU() , Linear(5,1),Sigmoid()]
X = np.random.randn(96,2)
y = (np.random.rand(96,1) > 0.5).astype(float) #hời nãy cái này mà dùng generate không trong [0,1] là chết


loss_func = BCE()
#X bây giờ cần shape là (cases,in_dims) = (96,2)
#y bây giờ cần shape là (cases,số cuối của layer cuối) = (96,1)
train(NN_demo, loss_func,X , y,1000 , 32,0.01)
# Out:
# Epoch  0  loss =  [[0.69345153]
#  [0.69359739]
#  [0.69259277]
#  [0.69351806]
#  [0.69247255]
#  [0.69278275]
#  [0.69368208]
#  [0.69378154]
#  [0.69350997]
#  [0.69341496]
#  [0.69390668]
#  [0.69350657]
#  [0.6935927 ]
#  [0.69277751]
#  [0.69264045]
#  [0.69271873]
#  [0.69370516]
#  [0.69242623]
#  [0.6928101 ]
#  [0.69358796]
#  [0.69364025]
#  [0.69345238]
#  [0.69232151]
#  [0.69345861]
#  [0.69353611]
#  [0.6928302 ]
#  [0.69362966]
#  [0.69266525]
#  [0.692725  ]
#  [0.69352149]
#  [0.69263401]
#  [0.69270995]]
# Epoch  50  loss =  [[0.66026669]
#  [0.80414952]
#  [0.72621385]
#  [0.65066758]
#  [0.70917911]
#  [0.70923391]
#  [0.74812258]
#  [0.71396013]
#  [0.59847256]
#  [0.66806371]
#  [0.66420601]
#  [0.59137061]
#  [0.65268943]
#  [0.73040661]
#  [0.63154084]
#  [0.67792491]
#  [0.67746546]
#  [0.6475232 ]
#  [0.71300966]
#  [0.70951132]
#  [0.73605017]
#  [0.64676829]
#  [0.65531473]
#  [0.64997367]
#  [0.72809212]
#  [0.67716733]
#  [0.77468812]
#  [0.72914326]
# ...
