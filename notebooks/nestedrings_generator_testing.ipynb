# %%
import sys
import os

PROJECT_ROOT = os.path.abspath("..")
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)
from data.generate import generate_nestedrings_data 

X,y = generate_nestedrings_data(100,42)
print("X , y ")
for i in range(100):
    print(X[i] ,"," ,y[i])
